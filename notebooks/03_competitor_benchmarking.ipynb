# %% [markdown]
# # Competitor Benchmarking & Industry Context
#
# This notebook provides competitive analysis and industry benchmarking for Flight Centre Travel Group.
#
# ## Objectives
# 1. Compare FLT metrics against key competitors
# 2. Assess competitive positioning
# 3. Identify competitive advantages and disadvantages
# 4. Provide industry context

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("Competitor Benchmarking Analysis")
print("\nKey competitors to analyze:")
print("- Expedia Group (EXPE)")
print("- Booking.com (BKNG)")
print("- Webjet Limited (WEB)")
print("- TravelCenters of America (TA)")

# %% [markdown]
# ## FLT Competitive Positioning

# %%
# FLT 2024 metrics
flt_metrics = {
    'Company': 'Flight Centre',
    'Revenue ($M)': 2711,
    'EBITDA Margin (%)': 17.65,
    'Net Margin (%)': 5.13,
    'ROE (%)': 11.56,
    'Debt-to-Equity': 2.50,
    'Geographic Focus': 'Australia, NZ, Americas, APAC',
    'Business Model': 'Travel agency + Online'
}

print("\nFlight Centre 2024 Profile:")
for key, value in flt_metrics.items():
    print(f"  {key}: {value}")

# %% [markdown]
# ## Industry Trends & Context

# %%
# Travel industry trends
print("\nTravel Industry Trends:")
print("\n1. Market Growth:")
print("   - Global travel market: 4-5% annual growth")
print("   - Online travel: 8-10% annual growth")
print("   - Post-COVID recovery: Strong through 2027")

print("\n2. Digital Transformation:")
print("   - Online bookings: 65-70% of market")
print("   - Mobile: 50%+ of online bookings")
print("   - AI/personalization: Growing importance")

print("\n3. Competitive Dynamics:")
print("   - Consolidation among travel agencies")
print("   - Direct booking pressure from hotels/airlines")
print("   - New entrants in niche segments")

print("\n4. Macro Factors:")
print("   - Rising middle class in Asia-Pacific")
print("   - Corporate travel recovery")
print("   - Sustainability/ESG considerations")

# %% [markdown]
# ## FLT Competitive Advantages

# %%
advantages = [
    "Strong brand recognition in ANZ markets",
    "Omnichannel presence (retail + online)",
    "Diversified revenue streams",
    "Established corporate travel relationships",
    "Geographic diversification",
    "Digital transformation momentum"
]

print("\nFLT Competitive Advantages:")
for i, adv in enumerate(advantages, 1):
    print(f"  {i}. {adv}")

# %% [markdown]
# ## FLT Competitive Challenges

# %%
challenges = [
    "Smaller scale vs. Expedia/Booking",
    "Higher cost structure (retail footprint)",
    "Margin pressure from online competition",
    "Dependency on travel demand",
    "Technology investment requirements",
    "Labor cost inflation"
]

print("\nFLT Competitive Challenges:")
for i, chall in enumerate(challenges, 1):
    print(f"  {i}. {chall}")
